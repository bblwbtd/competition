# %%
import pandas as pd

# %%
data = pd.read_excel('2018 APMCM Problems/2018 APMCM Problem B/Annex Job market of A-City Market Demand Statistics/2015/09.xlsx')

# %%
data
# Out:
#    2015.09.01 -- 2015.09.30  Market Demand Statistics  \
# 0                                                 S/N
# 1                                                 NaN
# 2                                                   1
# 3                                                   2
# 4                                                   3
# 5                                                   4
# 6                                                   5
# 7                                                   6
# 8                                                   7
# 9                                                   8
# 10                                                  9
# 11                                                 10
# 12                                                 11
# 13                                                 12
# 14                                                 13
# 15                                                 14
# ...

# %%
data.drop([0,1,49],axis=0,inplace=True)

# %%
data.columns = ['A','B','']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-ffda4f2b3980> in <module>
# ----> 1 data.columns = ['A','B']
#
# c:\program files\python37\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# c:\program files\python37\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     644
#     645     def _set_axis(self, axis, labels):
# --> 646         self._data.set_axis(axis, labels)
#     647         self._clear_item_cache()
#     648
#
# ...
